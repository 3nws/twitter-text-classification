# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, TfidfTransformer
from nltk.stem.snowball import SnowballStemmer

import pandas as pd
import nltk
import joblib

nltk.download('stopwords')

stemmer = SnowballStemmer("english")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Enes\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
dataset_dir = 'sentiment140'
# dataset_dir = 'imdb'
# dataset_dir = 'coronaNLP'

# importing the processed dataframe 
df = joblib.load(f'../dataframes/df_{dataset_dir}_1.pkl')


df.head()
# Out:
#                                                tweet  sentiment
# 0       awww bummer shoulda got david carr third day          0
# 1  upset cant updat facebook text might cri resul...          0
# 2    dive mani time ball manag save 50 rest go bound          0
# 3                    whole bodi feel itchi like fire          0
# 4                   behav im mad whi becaus cant see          0

# %%
from collections import Counter

# Count unique words


def counter_word(text_col):
    count = Counter()
    for text in text_col.values:
        for word in text.split():
            count[word] += 1
    return count


counter = counter_word(df.iloc[:, 0])

from nltk.tokenize import RegexpTokenizer

token = RegexpTokenizer(r'[a-zA-Z0-9]+')

max_f = len(counter)

# n_gram = (1, 1)
n_gram = (1, 2)
# n_gram = (2, 2)

tfidf = TfidfVectorizer(max_features=max_f, stop_words='english',
                        ngram_range=n_gram, tokenizer=token.tokenize)
tfidf
# Out:
# TfidfVectorizer(max_features=402749, ngram_range=(1, 2), stop_words='english',
#                 tokenizer=<bound method RegexpTokenizer.tokenize of RegexpTokenizer(pattern='[a-zA-Z0-9]+', gaps=False, discard_empty=True, flags=<RegexFlag.UNICODE|DOTALL|MULTILINE: 56>)>)

# %%
X = df.iloc[:, 0]
y = df.iloc[:, 1]
from sklearn.model_selection import train_test_split

# X = ["car driven road", "truck driven highway"]

# X_train, X_test, y_train, y_test = train_test_split(
#     X, y, test_size=0.3, stratify=y, random_state=42)

tfidf = tfidf.fit(X)
# Out:
# c:\Users\Enes\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\feature_extraction\text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"

# %%
transformed = tfidf.transform(X)

# %%
tfidf.vocabulary_
# Out:
# {'awww': 29990,
#  'bummer': 52979,
#  'shoulda': 301988,
#  'got': 136688,
#  'david': 83418,
#  'carr': 58921,
#  'day': 83555,
#  'awww bummer': 30013,
#  'shoulda got': 301996,
#  'got david': 137182,
#  'upset': 365043,
#  'updat': 364460,
#  'facebook': 109279,
#  'text': 333437,
#  'cri': 78806,
#  'result': 284683,
#  'school': 294177,
#  'today': 344129,
#  'blah': 44347,
#  'upset updat': 365147,
#  'updat facebook': 364553,
#  'facebook text': 109422,
#  'school today': 294686,
#  'today blah': 344376,
#  'dive': 91784,
#  'mani': 216502,
#  'time': 340711,
#  'ball': 32721,
#  'manag': 216254,
#  'save': 292262,
#  '50': 7724,
#  'rest': 284412,
#  'bound': 48402,
#  'mani time': 216803,
#  'time ball': 340847,
#  'manag save': 216346,
#  'save 50': 292270,
#  'bodi': 46322,
#  'feel': 113122,
#  'itchi': 176699,
#  'like': 195979,
#  'bodi feel': 46349,
#  'feel itchi': 113512,
#  'itchi like': 176706,
#  'behav': 37574,
#  'im': 169281,
#  'mad': 213537,
#  'whi': 384859,
#  'becaus': 35306,
#  'behav im': 37576,
#  'im mad': 170941,
#  'mad whi': 213712,
#  'whi becaus': 384923,
#  'crew': 78790,
#  'need': 234258,
#  'hug': 165211,
#  'need hug': 234839,
#  'hey': 156117,
#  'long': 204156,
#  'yes': 399528,
#  'rain': 276559,
#  'bit': 42911,
#  'onli': 248386,
#  'lol': 202714,
#  'fine': 116491,
#  'thank': 333818,
#  'hey long': 156585,
#  'long time': 204511,
#  'time yes': 342431,
#  'yes rain': 399939,
#  'rain bit': 276610,
#  'bit onli': 43340,
#  'onli bit': 248578,
#  'bit lol': 43260,
#  'lol im': 203169,
#  'im fine': 170266,
#  'fine thank': 116679,
#  'k': 181181,
#  'nope': 240955,
#  'didnt': 88839,
#  'nope didnt': 240973,
#  'que': 273179,
#  'spring': 317297,
#  'break': 49650,
#  'plain': 263441,
#  'citi': 66988,
#  'snow': 310462,
#  'spring break': 317306,
#  'repierc': 283743,
#  'ear': 98975,
#  'repierc ear': 283744,
#  'bear': 34762,
#  'watch': 377615,
#  'thought': 338584,
#  'ua': 361446,
#  'loss': 206566,
#  'embarrass': 102387,
#  'bear watch': 34789,
#  'watch thought': 379005,
#  'count': 76724,
#  'idk': 167654,
#  'talk': 330298,
#  'anymor': 23119,
#  'idk whi': 167747,
#  'whi talk': 385548,
#  'talk anymor': 330333,
#  'wouldv': 393929,
#  'gun': 142270,
#  'realli': 279726,
#  'zac': 402420,
#  'snyder': 310550,
#  'gun realli': 142280,
#  'wish': 387382,
#  'miss': 223291,
#  'premier': 268540,
#  'wish got': 387781,
#  'got watch': 138569,
#  'watch miss': 378513,
#  'miss premier': 224732,
#  'holli': 159307,
#  'death': 86242,
#  'scene': 294040,
#  'hurt': 166105,
#  'sever': 298540,
#  'film': 115494,
#  'wri': 394495,
#  'director': 90851,
#  'cut': 80092,
#  'death scene': 86294,
#  'watch film': 378115,
#  'director cut': 90854,
#  'file': 115382,
#  'tax': 331385,
#  'file tax': 115448,
#  'ahh': 14501,
#  'ive': 177123,
#  'alway': 17835,
#  'want': 374310,
#  'rent': 283584,
#  'love': 208255,
#  'soundtrack': 315498,
#  'ahh ive': 14556,
#  'ive alway': 177155,
#  'alway want': 18312,
#  'want rent': 375899,
#  'rent love': 283610,
#  'love soundtrack': 210712,
#  'oh': 244473,
#  'dear': 86107,
#  'drink': 96827,
#  'forgotten': 122675,
#  'tabl': 329903,
#  'oh dear': 244728,
#  'day didnt': 84036,
#  'friend': 124645,
#  'ask': 25820,
#  'meet': 219775,
#  'mid': 221600,
#  'valley': 367355,
#  'todaybut': 346034,
#  'sigh': 303750,
#  'friend ask': 124706,
#  'ask meet': 25965,
#  'mid valley': 221619,
#  'ive time': 177694,
#  'time sigh': 341996,
#  'barista': 33409,
#  'bake': 32626,
#  'cake': 55895,
#  'ate': 26730,
#  'bake cake': 32633,
#  'cake ate': 55905,
#  'week': 381726,
#  'hope': 161020,
#  'week hope': 382057,
#  'blagh': 44345,
#  'class': 67264,
#  '8': 9034,
#  'tomorrow': 346911,
#  'class 8': 67282,
#  '8 tomorrow': 9157,
#  'hate': 149014,
#  'wake': 372512,
#  'peopl': 257803,
#  'hate wake': 150052,
#  'wake peopl': 372737,
#  'sleep': 307592,
#  'marley': 217340,
#  'cri sleep': 79007,
#  'sleep watch': 308331,
#  'watch marley': 378474,
#  'sad': 289878,
#  'im sad': 171644,
#  'ooooh': 249911,
#  'lesli': 193432,
#  'ok': 245985,
#  'wont': 389717,
#  'ok wont': 246478,
#  'wont mad': 389953,
#  'meh': 220195,
#  'lover': 211377,
#  'track': 350329,
#  'depress': 87790,
#  'everi': 105505,
#  'depress everi': 87807,
#  'everi time': 105662,
#  'some1': 311029,
#  'hack': 143770,
#  'account': 10905,
#  'aim': 15015,
#  'make': 214230,
#  'new': 236134,
#  'hack account': 143771,
#  'make new': 214941,
#  'promot': 271605,
#  'gear': 130077,
#  'groov': 141081,
#  'ride': 285631,
#  'b': 30387,
#  'anaheim': 20995,
#  'want promot': 375821,
#  'option': 250578,
#  'realiz': 279517,
#  'evalu': 105359,
#  'morn': 228360,
#  'work': 390708,
#  'afternoon': 13174,
#  'thought sleep': 338966,
#  'sleep option': 308104,
#  'tomorrow realiz': 347466,
#  'morn work': 229398,
#  'work afternoon': 390871,
#  'awe': 28906,
#  '1': 118,
#  'awe love': 28924,
#  'love 1': 208256,
#  '1 miss': 352,
#  'asian': 25799,
#  'eye': 108592,
#  'night': 238812,
#  'eye sleep': 108765,
#  'sleep night': 308080,
#  'sick': 303012,
#  'spent': 316552,
#  'hour': 163394,
#  'sit': 306189,
#  'shower': 302363,
#  'caus': 60200,
#  'stand': 317953,
#  'held': 154118,
#  'puke': 272416,
#  'champ': 61920,
#  'bed': 36011,
#  'ok im': 246204,
#  'im sick': 171773,
#  'sick spent': 303520,
#  'spent hour': 316602,
#  'hour sit': 163906,
#  'shower caus': 302400,
#  'caus sick': 60571,
#  'puke like': 272427,
#  'like champ': 196600,
#  'ill': 168190,
#  'tell': 332330,
#  'ya': 396000,
#  'stori': 320897,
#  'later': 189513,
#  'good': 134435,
#  'workin': 392585,
#  'ill tell': 169102,
#  'tell ya': 332740,
#  'later good': 189623,
#  'good day': 134754,
#  'day ill': 84409,
#  'ill workin': 169204,
#  'workin like': 392599,
#  'like hour': 197484,
#  'sorri': 314352,
#  'came': 56428,
#  'gmt1': 132348,
#  'sorri bed': 314411,
#  'bed time': 36533,
#  'time came': 340948,
#  'dont': 93809,
#  'think': 336725,
#  'know': 185152,
#  'kid': 182845,
#  'suitcas': 324484,
#  'dont depress': 94043,
#  'depress dont': 87804,
#  'dont think': 94854,
#  'think want': 338117,
#  'want know': 375382,
#  'know kid': 185773,
#  '812': 9250,
#  '123': 1484,
#  'gym': 143220,
#  '35': 5950,
#  '6': 8118,
#  '610': 8396,
#  'anoth': 22303,
#  'gonna': 133687,
#  'fli': 118727,
#  'girlfriend': 131582,
#  'bed class': 36139,
#  '6 class': 8144,
#  'anoth day': 22433,
#  'day gonna': 84271,
#  'gonna fli': 133929,
#  'fli miss': 118817,
#  'miss girlfriend': 224089,
#  'studi': 322017,
#  'practic': 268079,
#  'exam': 106962,
#  'realli dont': 279927,
#  'dont feel': 94149,
#  'feel like': 113543,
#  'like today': 199011,
#  'today got': 344853,
#  'got studi': 138336,
#  'studi tomorrow': 322270,
#  'tomorrow practic': 347441,
#  'practic exam': 268099,
#  'hes': 155536,
#  'reason': 280662,
#  'teardrop': 332022,
#  'guitar': 142166,
#  'heart': 153097,
#  'hes reason': 155944,
#  'reason teardrop': 280790,
#  'teardrop guitar': 332023,
#  'guitar onli': 142201,
#  'onli break': 248596,
#  'break heart': 49745,
#  'wanna': 373622,
#  'sad sad': 290402,
#  'sad dont': 290060,
#  'dont know': 94350,
#  'know whi': 186414,
#  'whi hate': 385174,
#  'hate feel': 149365,
#  'feel wanna': 113892,
#  'wanna sleep': 374137,
#  'soo': 313028,
#  'final': 115699,
#  'comfort': 71641,
#  'awww soo': 30131,
#  'soo wish': 313192,
#  'wish final': 387730,
#  'final comfort': 115863,
#  'comfort im': 71654,
#  'sad miss': 290297,
#  'fall': 110169,
#  'asleep': 26118,
#  'heard': 152777,
#  'traci': 350326,
#  'girl': 131037,
#  'famili': 110478,
#  'fall asleep': 110183,
#  'girl bodi': 131106,
#  'sad heart': 290166,
#  'heart break': 153128,
#  'break famili': 49719,
#  'yay': 396780,
#  'happi': 147479,
#  'job': 179264,
#  'mean': 218955,
#  'yay im': 397025,
#  'im happi': 170483,
#  'happi job': 147756,
#  'job mean': 179449,
#  'mean time': 219351,
#  'check': 63415,
#  'user': 366739,
#  'timelin': 342503,
#  'blackberri': 44176,
#  'look': 204814,
#  'twank': 355962,
#  'happen': 147112,
#  'ppl': 267898,
#  'prob': 269857,
#  'w': 370403,
#  'bgs': 40883,
#  'look like': 205389,
#  'happen ppl': 147332,
#  'ppl prob': 267992,
#  'prob w': 269985,
#  'iron': 175978,
#  'fave': 112463,
#  'wear': 380573,
#  'burnt': 53532,
#  'strang': 321254,
#  'lilo': 199453,
#  'befor': 36950,
#  'retweet': 284879,
#  'oh im': 244992,
#  'im sorri': 171900,
#  'sorri didnt': 314507,
#  'didnt think': 89388,
#  'think befor': 336866,
#  'broadband': 50880,
#  'plan': 263464,
#  'massiv': 217585,
#  'broken': 51114,
#  'promis': 271476,
#  'wait': 371136,
#  'broken promis': 51191,
#  'wow': 393974,
#  'ton': 347779,
#  'repli': 283813,
#  'unfollow': 363589,
#  'tweet': 356143,
#  'scroll': 295306,
#  'feed': 113041,
#  'lot': 207265,
#  'wow ton': 394327,
#  'unfollow friend': 363603,
#  'friend tweet': 125395,
#  'tweet scroll': 356788,
#  'duck': 97977,
#  'chicken': 64881,
#  'wayyy': 380488,
#  'hatch': 149008,
#  'wayyy long': 380493,
#  'vacat': 367178,
#  'photo': 260495,
#  'onlin': 249357,
#  'yrs': 401884,
#  'ago': 13698,
#  'pc': 257259,
#  'crash': 78003,
#  'forget': 122248,
#  'site': 306580,
#  'vacat photo': 367243,
#  'photo onlin': 260675,
#  'yrs ago': 401885,
#  'pc crash': 257270,
#  'sure': 327425,
#  'pos': 266944,
#  'trade': 350440,
#  'away': 28464,
#  'compani': 72187,
#  'asset': 26520,
#  'andi': 21069,
#  'sure onli': 327856,
#  'want dont': 374902,
#  'think trade': 338046,
#  'hate happen': 149453,
#  'dalla': 81655,
#  'gotta': 138690,
#  'say': 292882,
#  'youd': 401038,
#  'use': 365970,
#  'music': 231703,
#  'game': 128954,
#  'mmm': 225658,
#  'sad feel': 290107,
#  'gotta say': 138926,
#  'say youd': 293686,
#  'youd think': 401080,
#  'think use': 338096,
#  'use music': 366394,
#  'music game': 231824,
#  'degre': 87099,
#  'degre tomorrow': 87148,
#  'u': 359821,
#  'alreadi': 17179,
#  'sd': 295358,
#  'hmmm': 158685,
#  'random': 277324,
#  'glad': 131752,
#  'hear': 152242,
#  'yer': 399492,
#  'u thought': 361218,
#  'thought u': 339026,
#  'u alreadi': 359887,
#  'random u': 277419,
#  'u glad': 360401,
#  'glad hear': 131870,
#  'hear yer': 152771,
#  'ps3': 272045,
#  'commiss': 72015,
#  'wutcha': 395399,
#  'play': 263962,
#  'cop': 76076,
#  'blood': 45708,
#  'sand': 291591,
#  'miss ps3': 224746,
#  'leav': 191533,
#  'park': 255268,
#  'leav park': 192006,
#  'park lot': 255388,
#  'lot work': 207975,
#  'life': 194895,
#  'cool': 75516,
#  'life cool': 195019,
#  'gotten': 139018,
#  'experi': 108223,
#  'post': 267145,
#  'cigarett': 66869,
#  'sad ive': 290211,
#  'ive gotten': 177369,
#  'nice': 237890,
#  'bad': 31555,
#  'come': 70219,
#  '5am': 7988,
#  'nice day': 238044,
#  'day bad': 83724,
#  'bad rain': 32107,
#  'rain come': 276642,
#  'come tomorrow': 71402,
#  'tomorrow 5am': 346935,
#  'lost': 206609,
#  'pay': 257057,
#  'phone': 259779,
#  'lmao': 202125,
#  'aw': 27841,
#  'shuck': 302761,
#  'bad wont': 32333,
#  'wont lost': 389948,
#  'lost job': 206935,
#  'job pay': 179475,
#  'pay phone': 257159,
#  'phone lmao': 260122,
#  'lmao aw': 202134,
#  'aw shuck': 28018,
#  'damm': 81726,
#  'school tomorrow': 294697,
#  'mo': 225888,
#  'money': 227278,
#  'hell': 154139,
#  'min': 222292,
#  'wage': 371043,
#  '4': 6378,
#  'fn': 119945,
#  'clam': 67220,
#  'job money': 179455,
#  'forev': 122146,
#  'soon': 313207,
#  'algonquin': 16270,
#  'agre': 13927,
#  'saw': 292430,
#  'failwhal': 109839,
#  'allllll': 16529,
#  'allllll day': 16530,
#  'day today': 85231,
#  'haha': 143978,
#  'dude': 98000,
#  'em': 101889,
#  'unless': 364164,
#  'someon': 311132,
#  'ad': 12105,
#  'terribl': 333042,
#  'pop': 266713,
#  'oh haha': 244919,
#  'haha dude': 144206,
#  'dude dont': 98034,
#  'dont realli': 94625,
#  'realli look': 280174,
#  'look em': 205105,
#  'unless someon': 364199,
#  'someon say': 311451,
#  'say hey': 293188,
#  'hey ad': 156128,
#  'ad sorri': 12211,
#  'sorri im': 314641,
#  'im terribl': 172156,
#  'terribl need': 333085,
#  'need pop': 235138,
#  'right': 285962,
#  'start': 318389,
#  'nikster': 240119,
#  'jare': 178310,
#  'im sure': 172077,
#  'sure right': 327931,
#  'right need': 286536,
#  'need start': 235372,
#  'start work': 319082,
#  'diss': 91597,
#  'band': 32914,
#  'trace': 350321,
#  'clear': 67859,
#  'ugli': 362241,
#  'realli hate': 280072,
#  'hate peopl': 149723,
#  'attir': 27234,
#  'puma': 272577,
#  'singlet': 305581,
#  'adida': 12630,
#  'black': 43970,
#  'busi': 53847,
#  'sock': 310709,
#  'leather': 191520,
#  'shoe': 300841,
#  'lucki': 212287,
#  'run': 289169,
#  'ani': 21328,
#  'cute': 80276,
#  'leather shoe': 191526,
#  'run ani': 289199,
#  'ani cute': 21445,
#  'cute girl': 80353,
#  'locat': 202545,
#  'whi wont': 385653,
#  'picnic': 261978,
#  'smell': 309509,
#  'citrus': 67176,
#  'smell like': 309559,
#  'donkey': 93780,
#  'sensit': 297282,
#  'comment': 71772,
#  'hed': 153741,
#  'med': 219593,
#  'mug': 231222,
#  'asap': 25675,
#  'charger': 62947,
#  'awol': 29661,
#  'csi': 79479,
#  'tonight': 347887,
#  'fml': 119882,
#  'tonight fml': 348118,
#  'arm': 25213,
#  'sore': 314220,
#  'tenni': 332885,
#  'think arm': 336821,
#  'arm sore': 25265,
#  'wonder': 389316,
#  'unhappi': 363878,
#  'split': 316883,
#  'wonder whi': 389662,
#  'whi someon': 385498,
#  'someon u': 311540,
#  'u like': 360638,
#  'like make': 197823,
#  'make unhappi': 215376,
#  'bye': 55155,
#  'sleep soon': 308222,
#  'soon hate': 313361,
#  'hate say': 149826,
#  'say bye': 292996,
#  'bye tomorrow': 55278,
#  'tomorrow night': 347377,
#  'ur': 365217,
#  'newslett': 237689,
#  'fare': 111914,
#  'unbeliev': 363041,
#  'shame': 299142,
#  'book': 46853,
#  'paid': 253629,
#  'got ur': 138528,
#  'shame alreadi': 299144,
#  'alreadi book': 17244,
#  'missin': 225350,
#  'boo': 46680,
#  'missin boo': 225354,
#  'itm': 176920,
#  'damn': 81774,
#  'chalk': 61867,
#  'chalkboard': 61870,
#  'useless': 366725,
#  'damn dont': 81878,
#  'dont ani': 93850,
#  'blast': 44566,
#  'getti': 130531,
#  'villa': 369223,
#  'shes': 299718,
#  'throat': 339173,
#  'wors': 393390,
#  'hate shes': 149851,
#  'sore throat': 314309,
#  'throat day': 339193,
#  'day wors': 85429,
#  'sup': 326487,
#  'mama': 215682,
#  'hey miss': 156638,
#  'miss ya': 225292,
#  'ya meet': 396184,
#  'tummi': 354699,
#  'hypnosi': 166744,
#  'anyth': 23514,
#  'stop': 320321,
#  'smoke': 309941,
#  'tummi hurt': 354727,
#  'hurt wonder': 166446,
#  'anyth work': 23777,
#  'work stop': 392213,
#  'stop smoke': 320601,
#  'fat': 112227,
#  'whi alway': 384888,
#  'babe': 30754,
#  'fam': 110373,
#  'annoy': 22127,
#  'theyr': 335569,
#  'muahaha': 231095,
#  'evil': 106701,
#  'laugh': 190012,
#  'sorri babe': 314401,
#  'annoy thank': 22245,
#  'thank theyr': 334850,
#  'theyr asleep': 335588,
#  'asleep right': 26238,
#  'evil laugh': 106720,
#  'attent': 27197,
#  'cover': 77356,
#  'photoshop': 260905,
#  'webpag': 381244,
#  'design': 88050,
#  'undergrad': 363236,
#  'paid attent': 253651,
#  'design class': 88066,
#  'wednesday': 381576,
#  'bday': 34321,
#  '2': 2502,
#  'bday dont': 34356,
#  'know 2': 185158,
#  'poor': 266406,
#  'cameron': 56981,
#  'hill': 157909,
#  'pray': 268201,
#  'pleas': 264892,
#  'ex': 106829,
#  'threaten': 339124,
#  'sh': 298906,
#  'babi': 30866,
#  '1st': 2352,
#  'birthday': 42396,
#  'parti': 255588,
#  'jerk': 178891,
#  'headach': 151715,
#  'pray pleas': 268272,
#  'babi 1st': 30871,
#  '1st birthday': 2380,
#  'birthday parti': 42695,
#  'hmm': 158557,
#  'enjoy': 103702,
#  'problem': 270426,
#  'constant': 74687,
#  'thing': 335893,
#  'ulik': 362689,
#  'hmm u': 158662,
#  'u realli': 360941,
#  'realli enjoy': 279959,
#  'u think': 361214,
#  'think thing': 338013,
#  'thing someon': 336522,
#  'littl': 200834,
#  'puppi': 272684,
#  'sick littl': 303348,
#  'littl puppi': 201277,
#  'steve': 319890,
#  'sinc': 304629,
#  'easter': 99832,
#  'wnt': 388706,
#  'abl': 10151,
#  'ohh': 245710,
#  'parti sad': 255953,
#  'sad sinc': 290437,
#  'sinc easter': 304833,
#  'wnt b': 388708,
#  'b abl': 30397,
#  'abl 2': 10152,
#  'actual': 11505,
#  'bracket': 49335,
#  'pool': 266232,
#  'wasnt': 377077,
#  'hey actual': 156127,
#  'bad wasnt': 32311,
#  'follow': 120206,
#  'dont follow': 94170,
#  'follow work': 121111,
#  'nite': 240207,
#  'favorit': 112523,
#  'team': 331821,
#  'astro': 26661,
#  'spartan': 315967,
#  'lose': 206299,
#  'tw': 355952,
#  'bad nite': 32038,
#  'favorit team': 112675,
#  'northern': 241218,
#  'calif': 56212,
#  'polic': 266087,
#  'remain': 282812,
#  'california': 56217,
#  'bodi miss': 46385,
#  'northern california': 241219,
#  'california girl': 56228,
#  'increas': 173471,
#  'capac': 57745,
#  'fast': 112084,
#  'yesterday': 400213,
#  'pain': 253737,
#  'fail': 109629,
#  'whale': 384573,
#  '15': 1793,
#  'yesterday pain': 400433,
#  'pain got': 253839,
#  'got fail': 137343,
#  'fail whale': 109815,
#  '15 time': 1836,
#  'time 2': 340726,
#  '2 hour': 3121,
#  'class work': 67537,
#  'quothousequot': 274708,
#  'rememb': 282854,
#  'bum': 52822,
#  'leg': 192943,
#  'strike': 321663,
#  'kind': 183878,
#  'complaint': 72454,
#  'laptop': 188708,
#  'overh': 252427,
#  'recal': 280873,
#  'cool kind': 75731,
#  'emili': 102466,
#  'mommi': 226769,
#  'train': 350720,
#  'train new': 350872,
#  'new job': 236715,
#  'job miss': 179451,
#  'send': 296761,
#  'messag': 220901,
#  '3rd': 6310,
#  'mix': 225513,
#  'sophmor': 314202,
#  'year': 398481,
#  'parti send': 255964,
#  'send bad': 296786,
#  '3rd parti': 6340,
#  'send mix': 296944,
#  'sophmor year': 314203,
#  'overr': 252493,
#  'q': 273008,
#  'moscow': 229616,
#  'know heard': 185664,
#  'afternoon wonder': 13342,
#  'wonder thing': 389622,
#  'lay': 190624,
#  'voic': 369698,
#  'lay bed': 190634,
#  'bed voic': 36563,
#  'sooo': 313676,
#  'kill': 183505,
#  'kutner': 186966,
#  'hous': 164108,
#  'whyyyyyyyy': 386189,
#  'im sooo': 171883,
#  'sooo sad': 313809,
#  'sad kill': 290227,
#  'kutner hous': 186969,
#  'mea': 218913,
#  'culpa': 79659,
#  'sorri tell': 314920,
#  'mea culpa': 218914,
#  'realli sorri': 280401,
#  'sens': 297192,
#  'suicid': 324453,
#  'refus': 281961,
#  'believ': 37665,
#  'didnt make': 89171,
#  'make ani': 214280,
#  'ani sens': 21743,
#  'thing refus': 336448,
#  'refus believ': 281968,
#  'believ actual': 37678,
#  'actual happen': 11725,
#  'hope ok': 161754,
#  'grind': 141021,
#  'inspir': 174380,
#  'sadden': 290610,
#  'cuz': 80594,
#  'time dont': 341123,
#  'dont want': 94954,
#  'want stop': 376184,
#  'stop cuz': 320396,
#  'cuz like': 80711,
#  'like u': 199086,
#  'u love': 360675,
#  'yeah': 397562,
#  'wudnt': 395359,
#  'chanc': 61968,
#  'yeah aw': 397608,
#  'aw know': 27950,
#  'stand chanc': 317971,
#  'ugh': 361660,
#  '130am': 1652,
#  'ugh sleep': 361981,
#  'hang': 146693,
#  'crooner': 79192,
#  'sing': 305172,
#  'suck': 323747,
#  'wanna sing': 374124,
#  'sing suck': 305370,
#  'sc': 293743,
#  'aaw': 10039,
#  'bh': 40943,
#  'quotmorningquot': 275067,
#  'aww': 29692,
#  'beach': 34476,
#  'ya im': 396139,
#  'im leav': 170829,
#  'aww wanna': 29937,
#  'wanna beach': 373681,
#  'beach w': 34684,
#  'w u': 370786,
#  'u girl': 360397,
#  'piss': 262788,
#  'radio': 276384,
#  'station': 319275,
#  'radio station': 276447,
#  'n': 232469,
#  'bday n': 34402,
#  'n dont': 232585,
#  'flip': 119192,
#  'upsid': 365166,
#  'head': 150986,
#  'ramen': 277216,
#  'sound': 315231,
#  'know life': 185813,
#  'thought head': 338772,
#  'sound good': 315316,
#  'mention': 220594,
#  'pain hurt': 253865,
#  'late': 189083,
#  'snack': 310169,
#  'glass': 132085,
#  'oj': 245980,
#  'bc': 34191,
#  'quotdown': 274344,
#  'sleepugh': 308590,
#  'late night': 189323,
#  'night snack': 239669,
#  'glass oj': 132134,
#  'bc im': 34229,
#  'hate sick': 149861,
#  'big': 41083,
#  'fan': 110963,
#  'camilla': 56991,
#  'bell': 38106,
#  'im big': 169582,
#  'big fan': 41279,
#  'camilla bell': 56992,
#  'wah': 371060,
#  'clip': 68162,
#  'filter': 115678,
#  'till': 340367,
#  'puter': 272939,
#  'someth': 311595,
#  'els': 101557,
#  'blame': 44457,
#  'broke': 50919,
#  'wait till': 372298,
#  'someth els': 311711,
#  'els 2': 101559,
#  '2 blame': 2677,
#  'ex 4': 106830,
#  'longer': 204591,
#  'term': 332970,
#  'week longer': 382126,
#  'longer longer': 204648,
#  'longer term': 204697,
#  'need im': 234854,
#  'im actual': 169372,
#  'cold': 69534,
#  'im cold': 169829,
#  'ehhh': 101268,
#  'weather': 380768,
#  'turn': 354949,
#  'ehhh dont': 101269,
#  'dont weather': 94964,
#  'weather gonna': 380883,
#  'gonna turn': 134351,
#  'turn ugli': 355381,
#  'cooooold': 76051,
#  'incred': 173481,
#  'stuff': 322390,
#  'rumbl': 289149,
#  'hope tummi': 162111,
#  'tummi rumbl': 354750,
#  'away soon': 28801,
#  'notic': 241820,
#  'told': 346484,
#  'id': 167014,
#  'agenc': 13641,
#  'said': 290809,
#  'told id': 346567,
#  'id work': 167316,
#  'work tomorrow': 392322,
#  'follow said': 120914,
#  'bedtim': 36711,
#  'aliv': 16330,
#  'tire': 342833,
#  'imma': 172864,
#  'tri': 351750,
#  'headstart': 152089,
#  'im miss': 171034,
#  'miss babe': 223472,
#  'babe long': 30798,
#  'aliv im': 16341,
#  'im tire': 172205,
#  ...}

# %%
tfidf.idf_
# Out:
# array([ 8.72133598, 12.9726843 , 13.32935924, ..., 12.9726843 ,
#        13.19582785, 13.66583148])

# %%
# from scipy.sparse.csc import csc_matrix

# transformed.todense()

# %%
# from sklearn.preprocessing import normalize

# a = [[0.46, 0, 0.33, 0.46, 0]]
# normalize(a)

# %%
joblib.dump(tfidf, f'../vectors/vectorizer_{dataset_dir}_{n_gram}_1.pkl')
# Out:
# ['../vectors/vectorizer_sentiment140_(1, 2)_1.pkl']

# %%
new_vector = joblib.load(
    f'../vectors/vectorizer_{dataset_dir}_{n_gram}_1.pkl')
new_vector
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6052/3629757504.py in <module>
#       1 new_vector = joblib.load(
# ----> 2     f'../vectors/vectorizer_{dataset_dir}_{n_gram}_1.pkl')
#       3 new_vector
#
# c:\Users\Enes\AppData\Local\Programs\Python\Python37\lib\site-packages\joblib\numpy_pickle.py in load(filename, mmap_mode)
#     585                     return load_compatibility(fobj)
#     586
# --> 587                 obj = _unpickle(fobj, filename, mmap_mode)
#     588     return obj
#
# c:\Users\Enes\AppData\Local\Programs\Python\Python37\lib\site-packages\joblib\numpy_pickle.py in _unpickle(fobj, filename, mmap_mode)
#     504     obj = None
#     505     try:
# --> 506         obj = unpickler.load()
#     507         if unpickler.compat_mode:
#     508             warnings.warn("The file '%s' has been generated with a "
#
# c:\Users\Enes\AppData\Local\Programs\Python\Python37\lib\pickle.py in load(self)
#    1079         try:
#    1080             while True:
# -> 1081                 key = read(1)
#    1082                 if not key:
#    1083                     raise EOFError
#
# c:\Users\Enes\AppData\Local\Programs\Python\Python37\lib\pickle.py in read(self, n)
#     263             return data
#     264         else:
# --> 265             return self.file_read(n)
#     266
#     267     def readline(self):
#
# KeyboardInterrupt:

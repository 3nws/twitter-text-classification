# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, TfidfTransformer
from nltk.stem.snowball import SnowballStemmer

import pandas as pd
import nltk
import joblib

nltk.download('stopwords')

stemmer = SnowballStemmer("english")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Enes\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
dataset_dir = 'sentiment140'
# dataset_dir = 'imdb'
# dataset_dir = 'coronaNLP'

# importing the processed dataframe 
df = joblib.load(f'../dataframes/df_{dataset_dir}.pkl')


df.head()
# Out:
#                                                tweet  sentiment
# 0       awww bummer shoulda got david carr third day          0
# 1  upset cant updat facebook text might cri resul...          0
# 2    dive mani time ball manag save 50 rest go bound          0
# 3                    whole bodi feel itchi like fire          0
# 4                   behav im mad whi becaus cant see          0

# %%
from collections import Counter

# Count unique words


# def counter_word(text_col):
#     count = Counter()
#     for text in text_col.values:
#         for word in text.split():
#             count[word] += 1
#     return count


# counter = counter_word(df.iloc[:, 0])

from nltk.tokenize import RegexpTokenizer

token = RegexpTokenizer(r'[a-zA-Z0-9]+')

# max_f = len(counter)

# n_gram = (1, 1)
n_gram = (1, 2)
# n_gram = (2, 2)

tfidf = TfidfVectorizer(max_features=50000, stop_words='english', ngram_range=n_gram, norm='l2',
                        tokenizer=token.tokenize)
tfidf
# Out:
# TfidfVectorizer(max_features=50000, ngram_range=(1, 2), stop_words='english',
#                 tokenizer=<bound method RegexpTokenizer.tokenize of RegexpTokenizer(pattern='[a-zA-Z0-9]+', gaps=False, discard_empty=True, flags=<RegexFlag.UNICODE|DOTALL|MULTILINE: 56>)>)

# %%
X = df.iloc[:, 0]
y = df.iloc[:, 1]
from sklearn.model_selection import train_test_split

# X = ["car driven road", "truck driven highway"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=42)

tfidf = tfidf.fit(X_train)
# Out:
# C:\Users\Enes\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\feature_extraction\text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"

# %%
transformed = tfidf.transform(X)

# %%
tfidf.vocabulary_
# Out:
# {'ill': 20252,
#  'live': 24584,
#  'rock': 35079,
#  'sinc': 37056,
#  'im': 20456,
#  'loop': 25273,
#  'video': 45308,
#  'hate': 17854,
#  'life': 23772,
#  'ill live': 20340,
#  'live rock': 24633,
#  'sinc im': 37079,
#  'hate life': 17917,
#  'sorri': 38259,
#  'opposit': 31029,
#  'woke': 48070,
#  'earli': 11369,
#  'sleep': 37318,
#  'im sorri': 21051,
#  'woke earli': 48088,
#  'earli sleep': 11408,
#  'ralph': 33865,
#  'voic': 45451,
#  'gone': 15405,
#  'pack': 31262,
#  'bag': 3976,
#  'follow': 13752,
#  'voic gone': 45453,
#  'pack bag': 31264,
#  'fail': 12700,
#  'english': 11858,
#  'histori': 18903,
#  'far': 12862,
#  'loss': 25309,
#  'hug': 19885,
#  'friend': 14256,
#  'pass': 31522,
#  'away': 3408,
#  'sorri loss': 38324,
#  'pass away': 31523,
#  'aha': 1671,
#  'confirm': 8181,
#  'suicid': 39496,
#  'wait': 45578,
#  'quickpwn': 33460,
#  'come': 7790,
#  'iphon': 21493,
#  'os': 31077,
#  '30': 710,
#  'upgrad': 44750,
#  'phone': 31946,
#  'iphon os': 21508,
#  'os 30': 31079,
#  'good': 15595,
#  'dinner': 10322,
#  'w': 45518,
#  'group': 16828,
#  'cover': 8536,
#  'dish': 10407,
#  'gather': 14892,
#  'use': 44908,
#  'good dinner': 15652,
#  'dinner w': 10350,
#  'use good': 44923,
#  'hay': 18096,
#  'n': 28593,
#  'class': 7437,
#  'haha': 17173,
#  '1st': 277,
#  'day': 9276,
#  '1st day': 280,
#  'omg': 30636,
#  'need': 28799,
#  'theyr': 40882,
#  'ps': 33283,
#  'sooo': 38148,
#  'stoke': 39048,
#  'guy': 16994,
#  'omg need': 30674,
#  'entertain': 11964,
#  'henc': 18556,
#  'recommend': 34402,
#  'home': 19037,
#  'sick': 36872,
#  'summer': 39511,
#  'suck': 39385,
#  'home sick': 19188,
#  'sick summer': 36941,
#  'summer suck': 39560,
#  'absolut': 1296,
#  'awar': 3389,
#  'better': 4875,
#  'choic': 7317,
#  'make': 26195,
#  'weekend': 47143,
#  'becaus': 4336,
#  'say': 35816,
#  'good weekend': 15883,
#  'becaus say': 4387,
#  'grey': 16788,
#  'sad': 35375,
#  'tonight': 42823,
#  'sad tonight': 35490,
#  'like': 23881,
#  'new': 29119,
#  'cd': 6903,
#  'dont': 10710,
#  'know': 22685,
#  'wish': 47822,
#  '22': 543,
#  'like new': 24154,
#  'new cd': 29151,
#  'dont know': 10805,
#  'know like': 22805,
#  'like wish': 24316,
#  'sun': 39585,
#  'attempt': 3243,
#  'increas': 21285,
#  'effort': 11608,
#  'ala': 1794,
#  'said': 35545,
#  'bath': 4151,
#  'couch': 8454,
#  'amp': 2258,
#  'book': 5570,
#  'immedi': 21225,
#  'futur': 14737,
#  'excit': 12423,
#  'awak': 3365,
#  'night': 29545,
#  'tide': 41583,
#  'hobo': 18985,
#  'ass': 3166,
#  'bring': 6017,
#  'excit like': 12447,
#  'awak night': 3377,
#  'yeah': 49361,
#  'wont': 48200,
#  'strict': 39192,
#  'probabl': 33126,
#  'ny': 30108,
#  'winter': 47808,
#  'money': 27905,
#  'yeah wont': 49489,
#  'im probabl': 20961,
#  'tweet': 43688,
#  'u': 44138,
#  'tweet u': 43783,
#  'way': 46732,
#  'east': 11454,
#  'ok': 30423,
#  'hope': 19322,
#  'feet': 13204,
#  'stay': 38925,
#  'dri': 11096,
#  'x': 49111,
#  'ok hope': 30452,
#  'stay dri': 38938,
#  'taylor': 40270,
#  't': 40065,
#  'o': 30115,
#  'belong': 4736,
#  'da': 9002,
#  'um': 44545,
#  'luca': 25933,
#  'till': 41640,
#  'pra': 32911,
#  'ontem': 30950,
#  'luca till': 25934,
#  'capit': 6626,
#  'fm': 13729,
#  'ball': 4017,
#  'anyon': 2816,
#  'anybodi': 2793,
#  'ani': 2569,
#  'spare': 38498,
#  'ticket': 41567,
#  'pleeeas': 32579,
#  'let': 23625,
#  'desper': 10018,
#  'anyon know': 2828,
#  'ani spare': 2628,
#  'let know': 23670,
#  'know im': 22789,
#  'im desper': 20634,
#  'got': 16016,
#  'revis': 34784,
#  'bed': 4427,
#  'routin': 35222,
#  'finish': 13481,
#  'shoot': 36715,
#  'great': 16591,
#  'place': 32287,
#  'fun': 14536,
#  'great place': 16696,
#  'sooo fun': 38159,
#  'left': 23519,
#  '4': 799,
#  'dead': 9755,
#  'overdos': 31194,
#  'sweet': 39971,
#  'soon': 38077,
#  'left 4': 23521,
#  '4 dead': 819,
#  'relax': 34534,
#  'piec': 32193,
#  'shit': 36655,
#  'music': 28501,
#  'stuff': 39276,
#  'piec shit': 32196,
#  'everyth': 12269,
#  'okay': 30506,
#  'care': 6699,
#  'safe': 35528,
#  'tomorrow': 42659,
#  'goodnight': 15912,
#  'everyth okay': 12296,
#  'tomorrow goodnight': 42704,
#  'screw': 36157,
#  '630am': 1047,
#  'time': 41703,
#  'work': 48366,
#  'time work': 42035,
#  'im like': 20835,
#  'laura': 23333,
#  'fag': 12698,
#  'tri': 43249,
#  'studi': 39233,
#  'exam': 12355,
#  'nooooo': 29891,
#  'roar': 35057,
#  'tri studi': 43400,
#  'studi exam': 39243,
#  'damn': 9092,
#  'pic': 32070,
#  'pic come': 32076,
#  'scrap': 36141,
#  'iplay': 21523,
#  'idea': 20180,
#  'destin': 10027,
#  'bloodi': 5425,
#  'outcom': 31122,
#  'matter': 26732,
#  'btw': 6173,
#  'open': 30994,
#  'mtv': 28422,
#  'movi': 28289,
#  'award': 3390,
#  'hilari': 18867,
#  'check': 7102,
#  'mtvcom': 28426,
#  'mtv movi': 28424,
#  'movi award': 28295,
#  'think': 41064,
#  'mother': 28245,
#  'induc': 21317,
#  'perform': 31835,
#  'anxieti': 2788,
#  'sunni': 39679,
#  'dayi': 9718,
#  'love': 25454,
#  'starbuck': 38773,
#  'love day': 25538,
#  'figur': 13308,
#  'happi': 17614,
#  'doe': 10541,
#  'right': 34864,
#  'everytim': 12310,
#  'weatherman': 46944,
#  'sound': 38401,
#  'sound like': 38420,
#  'gonna': 15438,
#  'thought': 41423,
#  'start': 38784,
#  '630': 1046,
#  'start like': 38831,
#  'nothin': 30015,
#  'sweat': 39958,
#  'plane': 32360,
#  'dure': 11297,
#  'sittin': 37240,
#  'gate': 14890,
#  'devil': 10051,
#  'besid': 4772,
#  'ice': 20101,
#  'cream': 8659,
#  'nothin like': 30016,
#  'dure summer': 11304,
#  'ice cream': 20105,
#  'read': 33942,
#  'comment': 8025,
#  'alway': 2040,
#  'bad': 3821,
#  'read comment': 33955,
#  'alway bad': 2044,
#  'bad idea': 3874,
#  'christin': 7348,
#  'hous': 19757,
#  'open hous': 31002,
#  'hous ill': 19784,
#  'feel': 13004,
#  'feel good': 13063,
#  'blend': 5332,
#  'harm': 17825,
#  'know suck': 22890,
#  'brat': 5901,
#  'sport': 38657,
#  'gave': 14898,
#  'troubl': 43486,
#  'break': 5913,
#  'good break': 15625,
#  'total': 43028,
#  'miss': 27381,
#  'ill total': 20420,
#  'total miss': 43061,
#  'miss guy': 27495,
#  'wtf': 49077,
#  '2': 290,
#  'tweetup': 43813,
#  'ladi': 23081,
#  'gaga': 14771,
#  'physic': 32061,
#  'fact': 12683,
#  'ladi gaga': 23085,
#  'sick dont': 36889,
#  'dont like': 10813,
#  'like fact': 24021,
#  'like music': 24151,
#  '3': 652,
#  'mind': 27301,
#  'close': 7545,
#  'mean': 26878,
#  'dont work': 10929,
#  'work 3': 48379,
#  '3 tomorrow': 702,
#  'tomorrow dont': 42691,
#  'dont mind': 10830,
#  'mean sleep': 26916,
#  'cute': 8902,
#  'sideway': 36975,
#  'cute pic': 8930,
#  'forgotten': 14008,
#  'person': 31856,
#  'wrote': 49072,
#  'anoth': 2678,
#  'excel': 12415,
#  'brought': 6132,
#  'tear': 40309,
#  'togeth': 42589,
#  'deserv': 10005,
#  'describ': 10002,
#  'terribl': 40465,
#  'wish togeth': 47992,
#  'friend dont': 14287,
#  'dont deserv': 10756,
#  'im miss': 20881,
#  'miss u': 27644,
#  'u guy': 44235,
#  'guy amp': 16999,
#  'amp im': 2373,
#  'im terribl': 21111,
#  'terribl sorri': 40472,
#  'today': 42242,
#  'end': 11785,
#  'pretti': 32998,
#  'guess': 16884,
#  'insid': 21373,
#  'head': 18118,
#  'burn': 6299,
#  'today end': 42314,
#  'pretti fun': 33025,
#  'thing': 40918,
#  'sorri miss': 38334,
#  'thing today': 41032,
#  'today got': 42347,
#  'british': 6049,
#  'polit': 32673,
#  'terribl day': 40466,
#  'graduat': 16522,
#  'babi': 3722,
#  'vet': 45275,
#  'vet today': 45276,
#  'retweet': 34770,
#  'duh': 11254,
#  'everyon': 12178,
#  'look': 25100,
#  'fabul': 12631,
#  'short': 36768,
#  'hair': 17389,
#  'wife': 47711,
#  'hahaha': 17336,
#  'everyon look': 12219,
#  'look fabul': 25137,
#  'short hair': 36772,
#  'hahaha love': 17350,
#  'yup': 49937,
#  'doesnt': 10589,
#  'add': 1470,
#  'thank': 40569,
#  'insight': 21379,
#  'peopl': 31682,
#  'thank thank': 40774,
#  'peopl read': 31756,
#  'expens': 12525,
#  'real': 34076,
#  'len': 23598,
#  'want': 45973,
#  'shirt': 36651,
#  'wear': 46861,
#  'vid': 45304,
#  'want say': 46207,
#  'love shirt': 25748,
#  'everi': 12123,
#  'friday': 14211,
#  'buy': 6401,
#  'greek': 16771,
#  'food': 13899,
#  'rice': 34830,
#  'salad': 35602,
#  'mix': 27703,
#  'watch': 46393,
#  'ate': 3207,
#  'everi friday': 12132,
#  'friday work': 14251,
#  'work buy': 48441,
#  'watch vid': 46669,
#  'shout': 36810,
#  'swedish': 39964,
#  'fan': 12808,
#  'fan love': 12821,
#  'love u': 25813,
#  'u know': 44263,
#  'background': 3796,
#  'twitter': 43864,
#  'page': 31297,
#  'mariah': 26637,
#  'realli': 34134,
#  'nice': 29382,
#  'new background': 29135,
#  'background twitter': 3800,
#  'twitter page': 43995,
#  'realli realli': 34268,
#  'realli nice': 34251,
#  'relat': 34531,
#  'las': 23183,
#  'vega': 45081,
#  'midnight': 27207,
#  'parti': 31462,
#  'las vega': 23184,
#  'midnight tonight': 27211,
#  'tonight parti': 42894,
#  'beauti': 4288,
#  'befor': 4571,
#  'awesom': 3463,
#  'dream': 11052,
#  'lava': 23341,
#  'tweet befor': 43701,
#  'befor head': 4602,
#  'head bed': 18124,
#  'bed realli': 4504,
#  'realli hope': 34210,
#  'hope feel': 19375,
#  'feel better': 13023,
#  'awesom dream': 3479,
#  'anim': 2646,
#  'clinic': 7536,
#  'orphan': 31073,
#  'duckl': 11223,
#  'didnt': 10098,
#  'didnt make': 10166,
#  'ahhh': 1704,
#  'tv': 43645,
#  'small': 37585,
#  'dose': 10961,
#  'day time': 9639,
#  'time tv': 42001,
#  'mhm': 27162,
#  'skin': 37265,
#  'xo': 49154,
#  'play': 32379,
#  'old': 30558,
#  'sesam': 36413,
#  'street': 39176,
#  'game': 14797,
#  'comput': 8096,
#  'ahahaha': 1678,
#  'mom': 27778,
#  'rid': 34842,
#  'favorit': 12941,
#  'tho': 41386,
#  'play old': 32434,
#  'use love': 44937,
#  'love game': 25586,
#  'mom got': 27801,
#  'got rid': 16310,
#  'upset': 44772,
#  'gay': 14907,
#  'realli upset': 34318,
#  'gay guy': 14909,
#  'help': 18482,
#  'confus': 8187,
#  'like dont': 24003,
#  'dont dont': 10758,
#  'dont help': 10789,
#  'aint': 1742,
#  'posit': 32785,
#  'type': 44127,
#  'set': 36417,
#  'warn': 46320,
#  'wasnt': 46343,
#  'wish wasnt': 48005,
#  'post': 32797,
#  'answer': 2761,
#  'u post': 44320,
#  'nobodi': 29832,
#  'hi': 18785,
#  'nobodi want': 29841,
#  'say hi': 35853,
#  'brother': 6107,
#  'twittervers': 44099,
#  'oh': 30207,
#  'whi': 47478,
#  'onli': 30759,
#  'prop': 33248,
#  'fair': 12721,
#  'oh whi': 30379,
#  'whi onli': 47560,
#  'onli 3': 30774,
#  'omfg': 30634,
#  'restrict': 34749,
#  'common': 8044,
#  'issu': 21640,
#  'think pretti': 41251,
#  'run': 35285,
#  'unsuccess': 44693,
#  'hurt': 19994,
#  'foot': 13939,
#  'hurt foot': 20011,
#  'listen': 24446,
#  'quotoff': 33622,
#  'appar': 2919,
#  'decid': 9808,
#  'record': 34409,
#  'anyth': 2852,
#  'anymor': 2800,
#  'hear': 18225,
#  'gig': 15026,
#  'anyth anymor': 2853,
#  'onli way': 30917,
#  'hear new': 18257,
#  'new stuff': 29290,
#  'conan': 8125,
#  'miss conan': 27445,
#  'night pretti': 29678,
#  'pretti sad': 33049,
#  'best': 4775,
#  'sure': 39796,
#  'seat': 36202,
#  'arrang': 3050,
#  'reall': 34133,
#  'ah': 1643,
#  'major': 26189,
#  'blackberri': 5288,
#  'ah yeah': 1668,
#  'major fail': 26190,
#  'hold': 18999,
#  'sale': 35606,
#  'item': 21656,
#  'shop': 36725,
#  'aw': 3329,
#  'sound aw': 38403,
#  'word': 48342,
#  'quotar': 33525,
#  'robot': 35073,
#  'quarter': 33426,
#  '10': 53,
#  'fridayquot': 14254,
#  'tast': 40243,
#  'tast like': 40247,
#  'stuf': 39273,
#  'went': 47325,
#  'clean': 7482,
#  'room': 35156,
#  'cook': 8284,
#  'cake': 6508,
#  'went shop': 47375,
#  'clean room': 7503,
#  'rain': 33759,
#  'nyc': 30111,
#  'ugh': 44452,
#  'need sleep': 28992,
#  'oh im': 30283,
#  'moni': 27933,
#  'work tomorrow': 48704,
#  'tomorrow make': 42731,
#  'learn': 23407,
#  'drink': 11101,
#  'lot': 25365,
#  'think need': 41227,
#  'need learn': 28917,
#  'drink lot': 11119,
#  'lot bad': 25367,
#  'sick day': 36886,
#  'mo': 27732,
#  'welcom': 47283,
#  'glad': 15159,
#  'enjoy': 11877,
#  'order': 31051,
#  'welcom glad': 47293,
#  'glad enjoy': 15170,
#  'free': 14128,
#  'guitar': 16956,
#  'lone': 25000,
#  'compani': 8053,
#  'femal': 13241,
#  'fall': 12744,
#  'south': 38451,
#  'dakota': 9077,
#  'im lone': 20846,
#  'lone compani': 25001,
#  'compani 22': 8054,
#  '22 femal': 545,
#  'south dakota': 38457,
#  'hehe': 18376,
#  'cross': 8765,
#  'offic': 30175,
#  'bibl': 5010,
#  'hehe dont': 18377,
#  'onli new': 30864,
#  'ebay': 11551,
#  'addict': 1486,
#  'quit': 33477,
#  'shitti': 36696,
#  'weather': 46887,
#  'plan': 32324,
#  'regard': 34500,
#  'shitti weather': 36699,
#  'question': 33440,
#  'werent': 47392,
#  'text': 40510,
#  'wish werent': 48012,
#  'away want': 3451,
#  'want text': 46249,
#  'birthday': 5130,
#  'lol': 24753,
#  'low': 25884,
#  'stress': 39183,
#  'want great': 46087,
#  'great today': 16733,
#  'today happi': 42358,
#  'happi birthday': 17627,
#  'birthday mom': 5161,
#  'mom lol': 27816,
#  'lol im': 24835,
#  'im glad': 20728,
#  'alway good': 2067,
#  'good thing': 15849,
#  'mcflys': 26859,
#  'concert': 8131,
#  'char': 7054,
#  '100': 74,
#  'workout': 48775,
#  'sin': 37054,
#  'yum': 49918,
#  'scream': 36146,
#  'divers': 10461,
#  'amaz': 2148,
#  'glad divers': 15168,
#  'divers amaz': 10462,
#  'amaz good': 2169,
#  'good day': 15648,
#  'day today': 9642,
#  'today love': 42404,
#  'love weather': 25831,
#  'black': 5275,
#  'cheer': 7161,
#  'loud': 25440,
#  'shit wish': 36688,
#  '13': 183,
#  'pictur': 32154,
#  'haha want': 17303,
#  'want pictur': 46183,
#  'cool': 8304,
#  'sunday': 39633,
#  'ur': 44789,
#  'famili': 12770,
#  'gulf': 16963,
#  'ur famili': 44814,
#  'sunday work': 39667,
#  'work day': 48462,
#  'news': 29342,
#  'air': 1756,
#  'franc': 14084,
#  'flight': 13675,
#  '12': 151,
#  'hour': 19656,
#  'air franc': 1761,
#  'franc flight': 14087,
#  '12 hour': 153,
#  'bad time': 3940,
#  'wouldnt': 48894,
#  'prove': 33272,
#  'wouldnt let': 48902,
#  'love x': 25850,
#  'im gonna': 20734,
#  'gonna miss': 15521,
#  'wanna': 45875,
#  'rich': 34832,
#  'weather amaz': 46889,
#  'instead': 21397,
#  'slowli': 37566,
#  'catch': 6813,
#  'saturday': 35713,
#  'blog': 5380,
#  'feed': 12998,
#  'sleep instead': 37392,
#  'instead im': 21398,
#  'im slowli': 21034,
#  'tweet blog': 43702,
#  'good stuff': 15840,
#  'whos': 47674,
#  'itali': 21645,
#  'know whos': 22933,
#  'wish enjoy': 47873,
#  'aww': 3569,
#  'neighbor': 29070,
#  'happen': 17559,
#  'socal': 37717,
#  'abt': 1312,
#  'aww sweet': 3609,
#  '2 bring': 315,
#  'bring u': 6037,
#  'doesnt happen': 10609,
#  'dude': 11227,
#  'onlin': 30927,
#  'forward': 14028,
#  'look forward': 25147,
#  'pregnant': 32958,
#  'kinda': 22557,
#  'good night': 15770,
#  'night tomorrow': 29718,
#  'tomorrow parti': 42747,
#  'parti plan': 31488,
#  'kinda miss': 22587,
#  'love hate': 25609,
#  'googl': 15947,
#  'doesnt help': 10610,
#  'oki': 30550,
#  'hun': 19944,
#  'lucki': 25971,
#  'rememb': 34587,
#  'soooo': 38186,
#  'nuffin': 30069,
#  'omg u': 30698,
#  'u lucki': 44287,
#  'lucki thing': 25988,
#  'aww love': 3595,
#  'love sinc': 25753,
#  'soooo good': 38195,
#  'haha x': 17314,
#  'x x': 49121,
#  'earlier': 11423,
#  'realli need': 34248,
#  'need start': 29001,
#  'start sleep': 38866,
#  'sleep earlier': 37359,
#  'pleasant': 32568,
#  'urban': 44887,
#  'outfitt': 31127,
#  'store': 39117,
#  'lt333': 25918,
#  'lol like': 24846,
#  'urban outfitt': 44888,
#  'dang': 9198,
#  'mav': 26749,
#  'forc': 13950,
#  '5': 935,
#  'gotta': 16436,
#  'credit': 8686,
#  'dislik': 10411,
#  'mark': 26650,
#  'cuban': 8810,
#  'hes': 18587,
#  'idiot': 20212,
#  'game 5': 14802,
#  'electron': 11651,
#  'looooong': 25265,
#  'bore': 5647,
#  'handl': 17503,
#  '40': 874,
#  'chang': 7012,
#  'plz': 32613,
#  'heard': 18285,
#  'number': 30076,
#  'chart': 7075,
#  'vote': 45470,
#  'great gig': 16638,
#  'thank vote': 40794,
#  'ali': 1848,
#  'day live': 9489,
#  'live twitter': 24645,
#  'twitter follow': 43930,
#  'bull': 6255,
#  'paper': 31397,
#  'unfortun': 44619,
#  'grass': 16575,
#  'hate time': 17975,
#  'look great': 25157,
#  'goin': 15373,
#  'send': 36318,
#  'im goin': 20730,
#  'send u': 36347,
#  'chester': 7215,
#  'french': 14174,
#  'everybodi': 12167,
#  'love everybodi': 25562,
#  'everybodi love': 12173,
#  'love music': 25693,
#  'bot': 5746,
#  'sit': 37183,
#  'yay': 49272,
#  'boy': 5809,
#  'sit home': 37202,
#  'sinc dont': 37071,
#  'tomorrow yay': 42799,
#  'yay miss': 49305,
#  'miss boy': 27421,
#  'ta': 40076,
#  'pilot': 32210,
#  'email': 11718,
#  'blast': 5315,
#  'starlight': 38781,
#  'bowl': 5799,
#  'site': 37223,
#  'facebook': 12657,
#  'account': 1337,
#  'got email': 16135,
#  'twitter facebook': 43919,
#  'facebook account': 12658,
#  'excus': 12493,
#  'lvatt': 26064,
#  'buy lvatt': 6424,
#  'saw': 35755,
#  'littl': 24502,
#  'kid': 22453,
#  'ride': 34847,
#  'poni': 32692,
#  'saw littl': 35779,
#  'littl kid': 24537,
#  'ride new': 34852,
#  'cute miss': 8927,
#  'omg love': 30671,
#  'love new': 25696,
#  'new hair': 29195,
#  'proverb': 33275,
#  'remind': 34612,
#  'quota': 33521,
#  'gentl': 14961,
#  'turn': 43598,
#  'turn away': 43603,
#  'love read': 25729,
#  'love tweet': 25810,
#  'butler': 6384,
#  'paddi': 31290,
#  'know end': 22735,
#  'got quit': 16297,
#  'quit like': 33494,
#  'tumblr': 43577,
#  'amus': 2527,
#  'burnt': 6309,
#  'finger': 13474,
#  'cricket': 8738,
#  'good start': 15836,
#  'burnt finger': 6311,
#  'right today': 34977,
#  'switzerland': 40036,
#  'hmmm': 18961,
#  'missin': 27676,
#  'boo': 5552,
#  'head home': 18136,
#  'bought': 5754,
#  'bought new': 5761,
#  'new guitar': 29193,
#  'want shirt': 46213,
#  'new pic': 29257,
#  'backpack': 3808,
#  'sweati': 39960,
#  'xbox360': 49132,
#  'garbag': 14862,
#  'dual': 11216,
#  'charact': 7056,
#  'luck': 25937,
#  'good luck': 15742,
#  'late': 23195,
#  'train': 43158,
#  'captain': 6633,
#  'gonna hate': 15493,
#  'pari': 31440,
#  '16': 219,
#  '16 day': 220,
#  'cabl': 6484,
#  'option': 31038,
#  'look like': 25171,
#  'haircut': 17428,
#  'cinnamon': 7397,
#  'choco': 7309,
#  'lolz': 24988,
#  'weekend time': 47226,
#  'time sleep': 41957,
#  'laundri': 23328,
#  'cox': 8545,
#  'instal': 21389,
#  'wrong': 49051,
#  'fix': 13597,
#  'wait till': 45732,
#  'till friday': 41664,
#  'friday come': 14216,
#  'school': 35986,
#  'school today': 36079,
#  'today hope': 42369,
#  'hope doesnt': 19361,
#  'pleasur': 32575,
#  'thanx': 40829,
#  'solid': 37758,
#  'blue': 5448,
#  'sky': 37284,
#  'cloud': 7577,
#  'stupid': 39327,
#  'blue sky': 5454,
#  'printchick': 33102,
#  'tell': 40355,
#  'link': 24398,
#  'interweb': 21457,
#  'fyi': 14751,
#  'talk': 40122,
#  'palin': 31356,
#  'cuz': 8956,
#  'respond': 34719,
#  'repli': 34650,
#  'dont talk': 10895,
#  'time way': 42025,
#  'way today': 46827,
#  'today cuz': 42301,
#  'plaza': 32493,
#  'metro': 27144,
#  'ipod': 21524,
#  'worth': 48880,
#  '7': 1066,
#  'wast': 46378,
#  'mexican': 27151,
#  'kitchen': 22631,
#  'disast': 10387,
#  'good time': 15853,
#  'time cook': 41762,
#  'mexican food': 27152,
#  'ive': 21702,
#  'crash': 8611,
#  'car': 6637,
#  'afta': 1566,
#  'gettin': 14998,
#  'crash car': 8612,
#  'hmm': 18950,
#  'paid': 31310,
#  'hmm ill': 18953,
#  'ill check': 20279,
#  'sux': 39931,
#  'wo': 48061,
#  'short day': 36770,
#  'cuz dont': 8958,
#  'dont ani': 10718,
#  'forgot': 13981,
#  'good rememb': 15807,
#  'rememb im': 34593,
#  'im littl': 20840,
#  'littl sad': 24559,
#  'breezi': 5965,
#  'love 2': 25455,
#  'differ': 10283,
#  'languag': 23154,
#  'let peopl': 23687,
#  'peopl know': 31727,
#  'haaaa': 17149,
#  'settl': 36433,
#  'long': 25010,
#  'half': 17439,
#  'shift': 36624,
#  'morn': 28038,
#  'anniversari': 2659,
#  'half hour': 17446,
#  'hour good': 19686,
#  'good news': 15768,
#  'news im': 29350,
#  'come morn': 7902,
#  'pen': 31666,
#  'hed': 18360,
#  'deliber': 9920,
#  'comedi': 8005,
#  'valu': 45048,
#  'onli think': 30900,
#  'know hes': 22782,
#  ...}

# %%
tfidf.idf_
# Out:
# array([ 8.73650918, 10.80772022, 11.74054025, ..., 10.98676845,
#        11.20502202, 11.69971826])

# %%
# from scipy.sparse.csc import csc_matrix

# transformed.todense()

# %%
# from sklearn.preprocessing import normalize

# a = [[0.46, 0, 0.33, 0.46, 0]]
# normalize(a)

# %%
joblib.dump(tfidf, f'../vectors/vectorizer_{dataset_dir}_{n_gram}.pkl')
# Out:
# ['../vectors/vectorizer_sentiment140_(1, 2).pkl']

# %%
new_vector = joblib.load(
    f'../vectors/vectorizer_{dataset_dir}_{n_gram}.pkl')
new_vector
# Out:
# TfidfVectorizer(max_features=50000, ngram_range=(1, 2), stop_words='english',
#                 tokenizer=<bound method RegexpTokenizer.tokenize of RegexpTokenizer(pattern='[a-zA-Z0-9]+', gaps=False, discard_empty=True, flags=<RegexFlag.UNICODE|DOTALL|MULTILINE: 56>)>)
